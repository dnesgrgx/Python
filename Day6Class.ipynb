# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dineshgurung/Library/Python/3.13/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dineshgurung/Library/Python/3.13/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/dineshgurung/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

labels = ['Paras', 'Dinesh', 'ABC', 'BCD']
age=[20, 19, 30, 40]
roll_no = [29, 15, 24, 15]

fig, ax = plt.subplots()

ax.bar(labels, age, label ='Pap')
ax.bar(labels, roll_no,bottom = age, label='Sap')

ax.set_ylabel('Age')
ax.set_xlabel('Student')
ax.set_title('Group of students')

ax.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

classes=["Python", "R", "AI", "ML", "DS"]
class1_Students=[30, 10, 20, 25, 10]
class2_Students=[40, 5, 20, 20, 10]

class_index=np.arange(len(classes))
width=0.2

plt.bar(class_index, class1_Students, width, label="class1 students")
plt.bar(class_index + width, class2_Students, width, label="class2 students")

plt.xticks(class_index+width, classes)

plt.title("Bar Chart of CLASSES")
plt.xlabel("Classes")
plt.ylabel("No. of students")
plt.show()

# %%
student = {
    "name": "Alex",
    "age": 20,
    "grade": "A+"
}

keys = list(student.keys())
values = list(student.values())

key1, key2, key3 = keys
val1, val2, val3 = values

print("Keys:", key1, key2, key3)
print("Values:", val1, val2, val3)
# Out:
# Keys: name age grade
# Values: Alex 20 A+

# %%
import matplotlib.pyplot as plt

student = {
    "name": "John",
    "age": 20,
    "grade": "A"
}

grade_value = 90

labels = ["Age", "Grade"]
values = [student["age"], grade_value]

plt.bar(labels, values, color=["blue", "green"])
plt.title("Student Info")
plt.xlabel("Attributes")
plt.ylabel("Values")
plt.ylim(0, 100)

plt.show()

# %%
import matplotlib.pyplot as plt

student = {
    "name": "John",
    "age": 20,
    "grade": "A"
}

labels = ["Age", "Grade"]
values = [student["age"], grade_value]

plt.scatter(labels, values)
plt.show()

# %%
import matplotlib.pyplot as plt

data = {'Batch 1': 10, 'Batch 2': 15, 'Batch 3':5, 'Batch 4': 20}
names = list(data.keys())
values = list(data.values())
x=100
plt.scatter(names, values, x, marker=r'$\clubsuit$')
plt.show()

# %%
import matplotlib.pyplot as plt

data = {'Batch 1': 10, 'Batch 2': 15, 'Batch 3':5, 'Batch 4': 20}
names = list(data.keys())
values = list(data.values())
x=400
plt.scatter(names, values, x, marker=r'$\alpha$')
plt.show()

# %%
import matplotlib.pyplot as plt

data = {'Batch 1': 10, 'Batch 2': 15, 'Batch 3':5, 'Batch 4': 20}
names = list(data.keys())
values = list(data.values())

plt.plot(names, values)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as num

# %%
#line plot
x_axis = num.array([0, 5, 10, 15, 20, 25, 30])
plt.plot(x_axis, x_axis*2)

plt.xlabel("X Axis")
plt.ylabel("Y Axis")

plt.title("My first plot")
# Out:
# Text(0.5, 1.0, 'My first plot')

# %%
plt.plot(x_axis, x_axis**2, 'red', label='x=y**2')
plt.legend()
plt.show()

# %%
y_axis = x_axis**2
empty_canvas = plt.figure()

create_axis = empty_canvas.add_axes([0, 0, 1, 1]) 

create_axis.plot(x_axis, y_axis, 'b')

create_axis = empty_canvas.add_axes([0, 0, 1, 1]) 

create_axis.plot(x_axis, y_axis, 'b', label = "x = x**2")
create_axis.plot(x_axis, y_axis+(x_axis*3), 'g', label = "x = y+(x*3)")

create_axis.legend(loc=0)

# %%
#SUBPLOT
import matplotlib.pyplot as plt

data = {'Batch 1': 10, 'Batch 2': 15, 'Batch 3': 5, 'Batch 4': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1,3, figsize=(10, 3))

axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)

fig.suptitle('Subplots')
# Out:
# Text(0.5, 0.98, 'Subplots')

# %%
import numpy as np
x = np.random.rand(200) > 0.7

barprops = dict(aspect='auto', cmap='binary')

fig = plt.figure()

ax1 = fig.add_axes([0.2, 0.2, 0.8, 0.2])

#ax1 = fig.add_axes([0.2, 0.2, 0.2, 0.8])
ax1.imshow(x.reshape((1, -1)), **barprops)

#ax1.imshow(x.reshape((-1, 1)), **barprops)

# %%
# %pip install qrcode
# Out:
# Collecting qrcode
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode

url = "https.//www.github.com/dnesgrgx/"
img = qrcode.make(url)
img.save("qr.png")
img.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

image = plt.imread('landscape.jpg')

fig, ax = plt.subplots()
im = ax.imshow(image)
patch = patches.Circle((300, 300), radius=500, transform=ax.transData)
im.set_clip_path(patch)

# %%
import numpy as np
all_data = [np.random.normal(0, x, size=20) for x in range(1,5)]
all_data
# Out:
# [array([ 1.50088643, -0.9381486 ,  0.60349626,  1.22363575,  0.10100706,
#         -0.76108346,  0.72822427, -0.85973829, -1.15684748,  1.40709067,
#         -0.60298768,  2.23710509, -0.15139185,  0.34008641,  0.92801074,
#         -1.9274161 , -1.25693066,  1.17865271, -0.55392473,  1.16361359]),
#  array([-0.21670918,  0.41579392, -0.8940429 , -1.4322089 ,  0.18062455,
#          0.2573864 ,  3.81098462, -0.23793173,  0.38275049,  0.39359899,
#          1.33828495, -1.85741498, -2.86190296, -0.06698864,  0.45850433,
#          0.64447401,  0.01178774,  1.40346775,  2.03545455, -1.73521217]),
#  array([-2.07091507,  5.88998919, -0.09034136, -0.62382878,  0.11811384,
#          1.1747885 , -4.58085652,  2.58894807, -0.58878967, -2.6780251 ,
#         -1.67881174, -2.27261645,  2.27200283,  7.40655898,  2.32673342,
#         -2.32298427,  0.9771199 , -1.18942128,  3.51972654,  2.82390888]),
#  array([-0.95965129, -4.21402448, -2.28508948, -4.70691378,  1.2123972 ,
#          0.98424263, -1.9892746 , 10.31625951,  5.08675678,  1.57453076,
#         -2.7159839 ,  7.54099685,  5.81232161,  0.95770183,  4.21265653,
#         -4.56026098, -2.44550738,  1.27857057, -5.24050924,  5.56037205])]

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['x1', 'x2', 'x3', 'x4']
#bplot1 = plt.boxplot(all_data, labels=labels)
bplot1 = plt.boxplot(all_data, 0, 'rs', 0, labels=labels)
plt.show()
# Out:
# /var/folders/f5/jwczvxv56rbfq3bjf6nwdy9w0000gn/T/ipykernel_5090/1397515473.py:6: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   bplot1 = plt.boxplot(all_data, 0, 'rs', 0, labels=labels)
# /var/folders/f5/jwczvxv56rbfq3bjf6nwdy9w0000gn/T/ipykernel_5090/1397515473.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bplot1 = plt.boxplot(all_data, 0, 'rs', 0, labels=labels)

# %%
#violinplot
import matplotlib.pyplot as plt
import numpy as np

all_data = [np.random.normal(0,x, size=50) for x in range(1, 5)]
vplot1 = plt.violinplot(all_data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

all_data = [np.random.normal(0,x, size=50) for x in range(1, 5)]
labels = ['x1', 'x2', 'x3', 'x4']

fig, axs = plt.subplots(1, 2, figsize=(12, 3))

axs[0].boxplot(all_data, labels=labels)
axs[1].violinplot(all_data)

fig.suptitle('Subplots')
# Out:
# /var/folders/f5/jwczvxv56rbfq3bjf6nwdy9w0000gn/T/ipykernel_5090/3571686779.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axs[0].boxplot(all_data, labels=labels)
# Text(0.5, 0.98, 'Subplots')

# %%
import matplotlib.pyplot as plt

all_data = [np.random.randn(100)]
plt.hist(all_data, bins=10)
# Out:
# (array([ 4.,  5.,  8., 17., 10., 15., 16., 13.,  7.,  5.]),
#  array([-2.2706703 , -1.86425947, -1.45784863, -1.0514378 , -0.64502697,
#         -0.23861613,  0.1677947 ,  0.57420553,  0.98061637,  1.3870272 ,
#          1.79343803]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt

data = {'Batch 1': 10, 'Batch 2': 15, 'Batch 3': 5, 'Batch 4': 20}
names = list(data.keys())
values = list(data.values())

plt.pie(values, labels=names, autopct='%0.1f%%')
plt.title("Batch Distribution")
plt.savefig("Fig.png", dpi = 300)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.text(0.1, 0.2, r'an equation: $E=mc^2$', fontsize=16)
plt.show()
